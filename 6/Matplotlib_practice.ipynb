# %% [markdown]
# # 👋 Matplotlib Hands-On
# * Index
#     * Single-Line
#     * Multiline
#     * Grid, Axes, and Labels
#     * Colors, Styles and Markers
#     * Subplots

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.2.2'

# %% [markdown]
# ## 📌 Single-Line

# %%
# 선그래프
x = [1,2,3,4,5,6]
y = [4,5,3,1,6,7]
plt.plot(x,y)
plt.show()

# %%
# 막대그래프
x = [1,2,3,4,5,6]
y = [4,5,3,1,6,7]
plt.bar(x,y)
plt.show()

# %%
# scatter 점 그래프
x = np.arange(0.0, 50.0, 2.0)
y = x**1.3 + np.random.rand(*x.shape)*3
plt.scatter(x, y)
plt.show()

# %% [markdown]
# ## 📌 Multiline

# %%
x = np.arange(7) # 0부터 6까지
y1 = -x**2
y2 = -x**3
y3 = -2*x
y4 = -2**x
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.plot(x,y4)
plt.show() # <- 블록의 끝이다!! (기억하기)
# pyplot style로 그리겠다.

# %%
x = np.arange(1,8) # 1부터 7까지
y1 = -x**2
y2 = -x**3
y3 = -2*x
y4 = -2**x
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.plot(x,y4)
plt.show() # <- 블록의 끝이다!! (기억하기)
# pyplot style로 그리겠다.

# %%
x = np.arange(0.0, 50.0, 2.0)
y1 = x**1.3 + np.random.rand(*x.shape)*3
y2 = x*1.3 + np.random.rand(*x.shape)*1.5
plt.scatter(x, y1)
plt.scatter(x, y2)
plt.show()

# x = np.arange(0.0, 50.0, 2.0)
# y = x**1.3 + np.random.rand(*x.shape)*30.0
# sizes = np.random.rand(*x.shape)*200 + 100 # 원 크기 조정
# print(sizes)
# plt.scatter(x, y, sizes, alpha = 0.3) # alpha는 투명도
# plt.show()

# %% [markdown]
# ## 📌 Grid, Axes, and Labels
#
# [legend 참고자료](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.legend.html#matplotlib.axes.Axes.legend)

# %%
x = np.arange(1,8) # 1부터 7까지
y1 = -x**2
y2 = -x**3
y3 = -2*x
y4 = -2**x
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.plot(x,y4)
plt.grid() # 격자 
# axes 조정
plt.xlim([4,6]) # x축 자르기
plt.ylim([-150,0]) # y축 자르기 
plt.show()

# %%
x = np.arange(1,8) # 1부터 7까지
y1 = -x**2
y2 = -x**3
y3 = -2*x
y4 = -2**x
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.plot(x,y4)
plt.grid() # 격자 
# axes 조정
plt.xlim([4,6]) # x축 자르기
plt.ylim([-150,0]) # y축 자르기 
# labels
plt.ylabel('y = f(x)')
plt.xlabel('x = np.arange(1,8)')
plt.legend() # warning 발생. 
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
x = np.arange(1,8) # 1부터 7까지
y1 = -x**2
y2 = -x**3
y3 = -2*x
y4 = -2**x
plt.plot(x,y1, label = 'y1 = -x**2')
plt.plot(x,y2, label = 'y2 = -x**3')
plt.plot(x,y3, label = 'y3 = -2*x')
plt.plot(x,y4, label = 'y4 = -2**x')
plt.grid() # 격자 
# axes 조정
plt.xlim([4,6]) # x축 자르기
plt.ylim([-150,0]) # y축 자르기 
# labels
plt.ylabel('y = f(x)')
plt.xlabel('x = np.arange(1,8)')
plt.title('Simple Plot Demo')
plt.legend() # warning 해결.
plt.show()

# %%
x = np.arange(1,8) # 1부터 7까지
y1 = -x**2
y2 = -x**3
y3 = -2*x
y4 = -2**x
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.plot(x,y4)
plt.grid() # 격자 
# axes 조정
plt.xlim([4,6]) # x축 자르기
plt.ylim([-150,0]) # y축 자르기 
# labels
plt.ylabel('y = f(x)')
plt.xlabel('x = np.arange(1,8)')
plt.title('Simple Plot Demo')
plt.legend([
    'y1 = -x**2',
    'y2 = -x**3',
    'y3 = -2*x',
    'y4 = -2**x'], loc = 'lower center') # 그래프 그리는 순서 같아야함. 
plt.show()

# %% [markdown]
# ## 📌 Colors, Styles and Markers

# %%
plt.bar?

# %%
# 막대그래프
x = [1,2,3,4,5,6]
y = [4,5,3,1,6,7]
plt.bar(x,y,color="green")
plt.show()

# %%
x = [1,2,3,4]
y = [4,5,3,1]
bar_labels = ['red','blue','red','orange']
bar_colors = ['tab:red','tab:blue','tab:red', 'tab:orange']
plt.bar(x,y,label = bar_labels, color=bar_colors)
plt.title('hello')
plt.ylabel('ylabel')
plt.legend()
plt.show()
# 결과를 보면, 라벨이 제대로 안나오는데 버전이 3.2.2 버전이라서 그렇다.

# %%
x = [1,2,3,4]
y = [4,5,3,1]
bar_labels = ['red','blue','red','orange']
bar_colors = ['tab:red','tab:blue','tab:red', 'tab:orange']

plt.bar(x[0],y[0],label = bar_labels[0], color=bar_colors[0])
plt.bar(x[1],y[1],label = bar_labels[1], color=bar_colors[1])
plt.bar(x[2],y[2],label = bar_labels[2], color=bar_colors[2])
plt.bar(x[3],y[3],label = bar_labels[3], color=bar_colors[3])

plt.title('hello')
plt.ylabel('ylabel')
plt.legend()
plt.show()

# %%
x = [1,2,3,4]
y = [4,5,3,1]
bar_labels = ['red','blue','red','orange']
bar_colors = ['tab:red','tab:blue','tab:red', 'tab:orange']

# 반복문으로 돌리기
for i,_ in enumerate(x):
  plt.bar(x[i],y[i],label = bar_labels[i], color=bar_colors[i])

plt.title('hello')
plt.ylabel('ylabel')
plt.legend()
plt.show()

# %%
plt.plot?

# %%
# markers
x = np.arange(1,8) 
y1 = -x**2
y2 = -x**3
y3 = -2*x
y4 = -2**x
# 마커 바꾸기
plt.plot(x,y1, 'yo')
plt.plot(x,y2, 'r+')
plt.plot(x,y3, 'go--')
plt.plot(x,y4)
plt.grid()  
plt.ylabel('y = f(x)')
plt.xlabel('x = np.arange(1,8)')
plt.title('Simple Plot Demo')
plt.legend([
    'y1 = -x**2',
    'y2 = -x**3',
    'y3 = -2*x',
    'y4 = -2**x'], loc = 'lower center') # 그래프 그리는 순서 같아야함. 
plt.savefig('fig1.pdf') # pdf 저장
plt.savefig('fig1.png') # png 저장
plt.savefig('fig1.svg') # svg 저장
plt.show()
